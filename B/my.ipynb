# %%
import pandas as pd
import numpy as np

# %%
transactions = pd.read_csv('data/transactions.csv')

# %%
transactions.head()
# Out:
#    customer_id tr_datetime  mcc_code  tr_type    amount term_id
# 0     39026145  0 10:23:26      4814     1030  -2245.92     NaN
# 1     39026145  1 10:19:29      6011     7010  56147.89     NaN
# 2     39026145  1 10:20:56      4829     2330 -56147.89     NaN
# 3     39026145  1 10:39:54      5499     1010  -1392.47     NaN
# 4     39026145  2 15:33:42      5499     1010   -920.83     NaN

# %%
days = np.empty(len(transactions))
for i in enumerate(transactions.tr_datetime):
    days[i[0]] = int(i[1].split()[0])
transactions['day'] = pd.Series(days)

# %%
mcc_code = transactions.mcc_code.unique()
days = transactions.day.unique()
days.sort()

# %%
timeSeries = pd.DataFrame()
for i in mcc_code:
    timeSeries[str(i)] = pd.Series(np.empty(len(days)))

# %%
k = 0
for mcc in mcc_code:
    for d in days:
        timeSeries[str(mcc)][d] = sum(transactions[(transactions.mcc_code == mcc) & (transactions.day == d)].amount)
        if(k % 100 == 0):
            print k
        k += 1
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
# 10400
# 10500
# 10600
# 10700
# 10800
# 10900
# 11000
# 11100
# 11200
# 11300
# 11400
# 11500
# 11600
# 11700
# 11800
# 11900
# 12000
# 12100
# 12200
# 12300
# 12400
# 12500
# 12600
# 12700
# 12800
# 12900
# 13000
# 13100
# 13200
# 13300
# 13400
# 13500
# 13600
# 13700
# 13800
# 13900
# 14000
# 14100
# 14200
# 14300
# 14400
# 14500
# 14600
# 14700
# 14800
# 14900
# 15000
# 15100
# 15200
# 15300
# 15400
# 15500
# 15600
# 15700
# 15800
# 15900
# 16000
# 16100
# 16200
# 16300
# 16400
# 16500
# 16600
# 16700
# 16800
# 16900
# 17000
# 17100
# 17200
# 17300
# 17400
# 17500
# 17600
# 17700
# 17800
# 17900
# 18000
# 18100
# 18200
# 18300
# 18400
# 18500
# 18600
# 18700
# 18800
# 18900
# 19000
# 19100
# 19200
# 19300
# 19400
# 19500
# 19600
# 19700
# 19800
# 19900
# 20000
# 20100
# 20200
# 20300
# 20400
# 20500
# 20600
# 20700
# 20800
# 20900
# 21000
# 21100
# 21200
# 21300
# 21400
# 21500
# 21600
# 21700
# 21800
# 21900
# 22000
# 22100
# 22200
# 22300
# 22400
# 22500
# 22600
# 22700
# 22800
# 22900
# 23000
# 23100
# 23200
# 23300
# 23400
# 23500
# 23600
# 23700
# 23800
# 23900
# 24000
# 24100
# 24200
# 24300
# 24400
# 24500
# 24600
# 24700
# 24800
# 24900
# 25000
# 25100
# 25200
# 25300
# 25400
# 25500
# 25600
# 25700
# 25800
# 25900
# 26000
# 26100
# 26200
# 26300
# 26400
# 26500
# 26600
# 26700
# 26800
# 26900
# 27000
# 27100
# 27200
# 27300
# 27400
# 27500
# 27600
# 27700
# 27800
# 27900
# 28000
# 28100
# 28200
# 28300
# 28400
# 28500
# 28600
# 28700
# 28800
# 28900
# 29000
# 29100
# 29200
# 29300
# 29400
# 29500
# 29600
# 29700
# 29800
# 29900
# 30000
# 30100
# 30200
# 30300
# 30400
# 30500
# 30600
# 30700
# 30800
# 30900
# 31000
# 31100
# 31200
# 31300
# 31400
# 31500
# 31600
# 31700
# 31800
# 31900
# 32000
# 32100
# 32200
# 32300
# 32400
# 32500
# 32600
# 32700
# 32800
# 32900
# 33000
# 33100
# 33200
# 33300
# 33400
# 33500
# 33600
# 33700
# 33800
# 33900
# 34000
# 34100
# 34200
# 34300
# 34400
# 34500
# 34600
# 34700
# 34800
# 34900
# 35000
# 35100
# 35200
# 35300
# 35400
# 35500
# 35600
# 35700
# 35800
# 35900
# 36000
# 36100
# 36200
# 36300
# 36400
# 36500
# 36600
# 36700
# 36800
# 36900
# 37000
# 37100
# 37200
# 37300
# 37400
# 37500
# 37600
# 37700
# 37800
# 37900
# 38000
# 38100
# 38200
# 38300
# 38400
# 38500
# 38600
# 38700
# 38800
# 38900
# 39000
# 39100
# 39200
# 39300
# 39400
# 39500
# 39600
# 39700
# 39800
# 39900
# 40000
# 40100
# 40200
# 40300
# 40400
# 40500
# 40600
# 40700
# 40800
# 40900
# 41000
# 41100
# 41200
# 41300
# 41400
# 41500
# 41600
# 41700
# 41800
# 41900
# 42000
# 42100
# 42200
# 42300
# 42400
# 42500
# 42600
# 42700
# 42800
# 42900
# 43000
# 43100
# 43200
# 43300
# 43400
# 43500
# 43600
# 43700
# 43800
# 43900
# 44000
# 44100
# 44200
# 44300
# 44400
# 44500
# 44600
# 44700
# 44800
# 44900
# 45000
# 45100
# 45200
# 45300
# 45400
# 45500
# 45600
# 45700
# 45800
# 45900
# 46000
# 46100
# 46200
# 46300
# 46400
# 46500
# 46600
# 46700
# 46800
# 46900
# 47000
# 47100
# 47200
# 47300
# 47400
# 47500
# 47600
# 47700
# 47800
# 47900
# 48000
# 48100
# 48200
# 48300
# 48400
# 48500
# 48600
# 48700
# 48800
# 48900
# 49000
# 49100
# 49200
# 49300
# 49400
# 49500
# 49600
# 49700
# 49800
# 49900
# 50000
# 50100
# 50200
# 50300
# 50400
# 50500
# 50600
# 50700
# 50800
# 50900
# 51000
# 51100
# 51200
# 51300
# 51400
# 51500
# 51600
# 51700
# 51800
# 51900
# 52000
# 52100
# 52200
# 52300
# 52400
# 52500
# 52600
# 52700
# 52800
# 52900
# 53000
# 53100
# 53200
# 53300
# 53400
# 53500
# 53600
# 53700
# 53800
# 53900
# 54000
# 54100
# 54200
# 54300
# 54400
# 54500
# 54600
# 54700
# 54800
# 54900
# 55000
# 55100
# 55200
# 55300
# 55400
# 55500
# 55600
# 55700
# 55800
# 55900
# 56000
# 56100
# 56200
# 56300
# 56400
# 56500
# 56600
# 56700
# 56800
# 56900
# 57000
# 57100
# 57200
# 57300
# 57400
# 57500
# 57600
# 57700
# 57800
# 57900
# 58000
# 58100
# 58200
# 58300
# 58400
# 58500
# 58600
# 58700
# 58800
# 58900
# 59000
# 59100
# 59200
# 59300
# 59400
# 59500
# 59600
# 59700
# 59800
# 59900
# 60000
# 60100
# 60200
# 60300
# 60400
# 60500
# 60600
# 60700
# 60800
# 60900
# 61000
# 61100
# 61200
# 61300
# 61400
# 61500
# 61600
# 61700
# 61800
# 61900
# 62000
# 62100
# 62200
# 62300
# 62400
# 62500
# 62600
# 62700
# 62800
# 62900
# 63000
# 63100
# 63200
# 63300
# 63400
# 63500
# 63600
# 63700
# 63800
# 63900
# 64000
# 64100
# 64200
# 64300
# 64400
# 64500
# 64600
# 64700
# 64800
# 64900
# 65000
# 65100
# 65200
# 65300
# 65400
# 65500
# 65600
# 65700
# 65800
# 65900
# 66000
# 66100
# 66200
# 66300
# 66400
# 66500
# 66600
# 66700
# 66800
# 66900
# 67000
# 67100
# 67200
# 67300
# 67400
# 67500
# 67600
# 67700
# 67800
# 67900
# 68000
# 68100
# 68200
# 68300
# 68400
# 68500
# 68600
# 68700
# 68800
# 68900
# 69000
# 69100
# 69200
# 69300
# 69400
# 69500
# 69600
# 69700
# 69800
# 69900
# 70000
# 70100
# 70200
# 70300
# 70400
# 70500
# 70600
# 70700
# 70800
# 70900
# 71000
# 71100
# 71200
# 71300
# 71400
# 71500
# 71600
# 71700
# 71800
# 71900
# 72000
# 72100
# 72200
# 72300
# 72400
# 72500
# 72600
# 72700
# 72800
# 72900
# 73000
# 73100
# 73200
# 73300
# 73400
# 73500
# 73600
# 73700
# 73800
# 73900
# 74000
# 74100
# 74200
# 74300
# 74400
# 74500
# 74600
# 74700
# 74800
# 74900
# 75000
# 75100
# 75200
# 75300
# 75400
# 75500
# 75600
# 75700
# 75800
# 75900
# 76000
# 76100
# 76200
# 76300
# 76400
# 76500
# 76600
# 76700
# 76800
# 76900
# 77000
# 77100
# 77200
# 77300
# 77400
# 77500
# 77600
# 77700
# 77800
# 77900
# 78000
# 78100
# 78200
# 78300
# 78400
# 78500
# 78600
# 78700
# 78800
# 78900
# 79000
# 79100
# 79200
# 79300
# 79400
# 79500
# 79600
# 79700
# 79800
# 79900
# 80000
# 80100
# 80200
# 80300
# 80400
# 80500
# 80600
# 80700
# 80800
# 80900
# 81000
# 81100
# 81200
# 81300
# 81400
# 81500
# 81600
# 81700
# 81800
# 81900
# 82000
# 82100
# 82200
# 82300
# 82400
# 82500
# 82600
# 82700
# 82800
# 82900
# 83000
# 83100
# 83200
# 83300
# 83400
# 83500
# 83600
# 83700
# 83800
# 83900
# 84000

# %%
len(days) * len(mcc_code)
# Out:
# 84088

# %%
timeSeries = pd.read_csv('timeSeries.csv')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
font = {'family': 'Verdana',
        'weight': 'normal'}
rc('font', **font)

# %%
mcc_table = pd.read_csv('data/tr_mcc_codes.csv', sep = ";")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5fe9c8f50397> in <module>()
# ----> 1 mcc_table = pd.read_csv('data/tr_mcc_codes.csv', sep = ";")
#
# NameError: name 'pd' is not defined

# %%
mcc_table
# Out:
#                               mcc_code,mcc_description
# 0                              742,������������ ������
# 1    1711,����������� ���������� �� ����������, ���...
# 2                     1731,���������� �� �������������
# 3    1799,����������, ������������������ �������� �...
# 4        2741,������������� ������������/�������� ����
# 5                         3000,���������, ������������
# 6                 3351,��������� �� ������ �����������
# 7                  3501,����� � �����, ������, �������
# 8    4111,��������������� � ����������� � ���������...
# 9                 4112,������������ �������� ���������
# 10                               4121,�������� � �����
# 11                               4131,���������� �����
# 12   4214,��������� �� ���������������� ����������,...
# 13   4215,������ ������� � �� ������� � �� �����, �...
# 14                                 4411,�������� �����
# 15   4511,���������, ������������, ����� ����� �� �...
# 16   4722,������������� ��������� � ������������ ��...
# 17             4784,�������� � �������� �����, �������
# 18   4789,������ �� ��������������� � ����� ����� �...
# 19   4812,�������������������� ������������, ������...
# 20   4814,������ � �������������� ���������, ������...
# 21        4816,������������ ����/�������������� ������
# 22                              4829,�������� ��������
# 23   4899,��������� � ������ ������� ������������� ...
# 24   4900,������������ ������ � �������������, ���,...
# 25              5013,���������� ���������� � ���������
# 26   5039,������������ ��������� � ����� ����� �� �...
# 27   5044,�������, ���������������, ���������������...
# 28   5045,����������, ������������ ������������ ���...
# 29   5047,�����������������/������������/����������...
# ..                                                 ...
# 154                                    7832,����������
# 155                                   7841,�����������
# 156            7922,����������� ������������ ���������
# 157                                7932,��������-�����
# 158                                 7933,�������-�����
# 159               7991,������������� ����������� � ���
# 160                   7993,�������������� ��� ��������
# 161                   7994,�������/���������� ��������
# 162                  7995,���������� �� �������� �����
# 163  7996,����-�����, ���������, �����, �����������...
# 164  7997,����� � �������� �����, ��������(��������...
# 165  7999,������ ������, ����� ����� �� �����������...
# 166      8011,�������, ����� ����� �� ����������������
# 167                        8021,��������, ������������
# 168              8043,������, ���������� ������ � ����
# 169                                      8062,��������
# 170              8071,������ � ����������� �����������
# 171  8099,������������ �����, ����������� ������, �...
# 172  8220,��������, ������������, ���������������� ...
# 173                   8244,����� � ������ � ����������
# 174                        8299,��������������� ������
# 175  8398,����������� ����������������� � ���������...
# 176  8641,���������� � �����������, ���������� � ��...
# 177  8699,�����������, ��������, ����� ����� �� ���...
# 178  8999,���������������� ������, ����� ����� �� �...
# 179  9211,������� �������, ������� �������� � �����...
# 180                                        9222,������
# 181                             9311,��������� �������
# 182  9399,����������������� ������, ����� ����� �� ...
# 183        9402,�������� ������ � ������ �������������
#
# [184 rows x 1 columns]

# %%
mcc_table[mcc_table.mcc_code == 4814].mcc_description
# Out:
# 20    Звонки с использованием телефонов, считывающих...
# Name: mcc_description, dtype: object

# %%
for i in mcc_code:
    fig1 = plt.figure(figsize=(20, 10))
    plt.title(mcc_table.mcc_description.ix[0])
    ax1 = fig1.add_subplot(111)
    ax1.plot(timeSeries[str(i)])
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-51-72e618654108> in <module>()
#       1 for i in mcc_code:
#       2     fig1 = plt.figure(figsize=(20, 10))
# ----> 3     plt.title(mcc_table.mcc_description.ix[0])
#       4     ax1 = fig1.add_subplot(111)
#       5     ax1.plot(timeSeries[str(i)])
#
# C:\Python27\lib\site-packages\matplotlib\pyplot.pyc in title(s, *args, **kwargs)
#    1347
#    1348     """
# -> 1349     l =  gca().set_title(s, *args, **kwargs)
#    1350     draw_if_interactive()
#    1351     return l
#
# C:\Python27\lib\site-packages\matplotlib\axes\_axes.pyc in set_title(self, label, fontdict, loc, **kwargs)
#     140             'verticalalignment': 'baseline',
#     141             'horizontalalignment': loc.lower()}
# --> 142         title.set_text(label)
#     143         title.update(default)
#     144         if fontdict is not None:
#
# C:\Python27\lib\site-packages\matplotlib\text.pyc in set_text(self, s)
#    1026         ACCEPTS: string or anything printable with '%s' conversion.
#    1027         """
# -> 1028         self._text = '%s' % (s,)
#    1029
#    1030     @staticmethod
#
# UnicodeDecodeError: 'ascii' codec can't decode byte 0xd0 in position 0: ordinal not in range(128)

# %%
i = 4814
fig1 = plt.figure(figsize=(20, 10))
plt.title(mcc_table.mcc_description.ix[0])
ax1 = fig1.add_subplot(111)
ax1.plot(timeSeries[str(i)])
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-26-a1e5f189e555> in <module>()
#       1 i = 4814
#       2 fig1 = plt.figure(figsize=(20, 10))
# ----> 3 plt.title(mcc_table.mcc_description.ix[0])
#       4 ax1 = fig1.add_subplot(111)
#       5 ax1.plot(timeSeries[str(i)])
#
# C:\Python27\lib\site-packages\matplotlib\pyplot.pyc in title(s, *args, **kwargs)
#    1347
#    1348     """
# -> 1349     l =  gca().set_title(s, *args, **kwargs)
#    1350     draw_if_interactive()
#    1351     return l
#
# C:\Python27\lib\site-packages\matplotlib\axes\_axes.pyc in set_title(self, label, fontdict, loc, **kwargs)
#     140             'verticalalignment': 'baseline',
#     141             'horizontalalignment': loc.lower()}
# --> 142         title.set_text(label)
#     143         title.update(default)
#     144         if fontdict is not None:
#
# C:\Python27\lib\site-packages\matplotlib\text.pyc in set_text(self, s)
#    1026         ACCEPTS: string or anything printable with '%s' conversion.
#    1027         """
# -> 1028         self._text = '%s' % (s,)
#    1029
#    1030     @staticmethod
#
# UnicodeDecodeError: 'ascii' codec can't decode byte 0xc2 in position 0: ordinal not in range(128)

# %%
unicode(mcc_table.mcc_description.ix[0])
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-16-a0dc6007b607> in <module>()
# ----> 1 unicode(mcc_table.mcc_description.ix[0])
#
# UnicodeDecodeError: 'ascii' codec can't decode byte 0xd0 in position 0: ordinal not in range(128)

# %%
from scipy.stats.stats import pearsonr

# %%
pearsonr(timeSeries["4814"][0:30], timeSeries["4814"][365:395])
# Out:
# (0.19136933601935147, 0.31104274893918049)

# %%
pearsonr(timeSeries["4814"][0:30], timeSeries["4814"][31:61])
# Out:
# (-0.075419449295852078, 0.69203015160485237)

# %%
# %pylab inline
import pandas as pd
from scipy import stats
import statsmodels.api as sm
import matplotlib.pyplot as plt
import warnings
from itertools import product
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
mcc_code
# Out:
# array([4814, 6011, 4829, 5499, 5541, 5200, 5732, 6010, 5331, 5912, 5411,
#        5812, 6012, 5719, 5722, 5621, 5814, 5921, 5941, 5691, 5813, 5211,
#        4812, 5945, 5983, 5999, 5943, 5533, 6300, 7832, 8099, 5992, 3501,
#        6536, 7997, 5641, 4722, 5661, 5651, 7011, 5699, 5942, 7298, 7999,
#        5712, 5511, 5422, 5399, 4900, 7538, 5949, 5977, 5948, 5631, 5311,
#        5462, 4112, 8999, 8021, 5714, 5251, 4789, 7542, 5947, 3000, 8043,
#        5944, 5734, 5611, 5532, 4816, 7311, 5655, 6051, 7994, 5995, 5309,
#        5964, 8299, 8244, 4111, 4511, 9399, 5441, 7922, 5261, 7699, 7995,
#        7629, 5816, 5735, 5039, 5300, 5199, 4121, 5065, 7399, 7299, 8011,
#        7230, 9222, 5946, 5131, 5994, 5231, 8071, 5094, 5047, 5072, 7210,
#        5976, 5045, 7932, 4215, 5542, 5099, 5713, 4899, 7933, 5681, 5193,
#        1711, 6211, 8398, 5599, 5993, 8062, 5169, 4214, 5733, 5013, 7221,
#        5571, 7993, 5971, 5968, 7372, 5074, 5044, 5811, 5111, 8641, 7512,
#        7523, 9311, 8220, 7991, 7996, 4784, 5931, 7841, 3351, 4411, 1799,
#        5192, 5122,  742, 6513, 7278, 5969, 5970, 4131, 5965, 7395, 5950,
#        5085, 7273, 5137, 5310, 7531, 7829, 7375, 2741, 5172, 8699, 7216,
#        5451, 5967, 7338, 9402, 5697, 1731, 5940, 9211], dtype=int64)

# %%
plt.figure(figsize(15,8))
ax = plt.subplot(211)
sm.graphics.tsa.plot_acf(timeSeries["6011"].values.squeeze(), lags=90, ax=ax)
pylab.show()
ax = plt.subplot(212)
sm.graphics.tsa.plot_pacf(timeSeries["6011"].values.squeeze(), lags=90, ax=ax)
pylab.show()

# %%
pearsonr(timeSeries["4814"][450:457], timeSeries["4814"][443:450])[0]
# Out:
# 0.78141062637643666

# %%
result = 
for i in mcc_code:

# %%
from sklearn import linear_model

# %%
a = linear_model.LinearRegression()

# %%
timeSeries["4814"][450:457].as_matrix()
# Out:
# -11704172.699999999

# %%
range(457, 487)
# Out:
# [457,
#  458,
#  459,
#  460,
#  461,
#  462,
#  463,
#  464,
#  465,
#  466,
#  467,
#  468,
#  469,
#  470,
#  471,
#  472,
#  473,
#  474,
#  475,
#  476,
#  477,
#  478,
#  479,
#  480,
#  481,
#  482,
#  483,
#  484,
#  485,
#  486]

# %%
result =
